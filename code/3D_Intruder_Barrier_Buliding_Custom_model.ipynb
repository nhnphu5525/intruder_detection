# %%
import cv2
import numpy as np
import time
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort

# %%
# Load model
model = YOLO("model/HumanDetection.pt")

# Initialize DeepSORT tracker
tracker = DeepSort(max_age=10)

# 3D Intrusion Zone (choosed by user)
intrusion_zone_3D = {}
current_zone = []
zone_id = 1
ZONE_HEIGHT = 180  # Height of the zone in cm

# Store intrusion logs
intrusion_timers = {}
intrusion_logs = {"zone_1": {}, "zone_2": {}}
INTRUSION_THRESHOLD = 3  # Time in seconds

# Video path
vid_path = "mall_test.mp4"

# %%
def mouse_callback(event, x, y, flags, param):
    global current_zone
    if event == cv2.EVENT_LBUTTONDOWN:
        current_zone.append((x, y))
    elif event == cv2.EVENT_RBUTTONDOWN and current_zone:
        current_zone.pop()

def create_intrusion_zone():
    global zone_id, intrusion_zone_3D, current_zone
    if len(current_zone) < 3:
        print("Please choose at least 3 points.")
        return
    bottom = np.array([[x, y, 0] for x, y in current_zone], np.float32)
    top = np.array([[x, y, ZONE_HEIGHT] for x, y in current_zone], np.float32)
    
    opening_time = input(f"Enter opening time for zone_{zone_id} (HH:MM:SS): ")
    closing_time = input(f"Enter closing time for zone_{zone_id} (HH:MM:SS): ")
    
    intrusion_zone_3D[f"zone_{zone_id}"] = {
        "bottom": bottom,
        "top": top,
        "closing_time": closing_time,
        "opening_time": opening_time
    }
    zone_id += 1
    current_zone = []
    print(f"Successfully created intrusion zone_{zone_id - 1} with open time {opening_time} - {closing_time}")

def is_person_inside_intrusion_zone(bbox, zone):
    x_min, y_min, x_max, y_max = bbox
    foot_x = (x_min + x_max) // 2
    foot_y = y_max
    height = (y_max - y_min) * 1.68 / 150  # Estimate the height of the person
    foot_point = np.array([foot_x, foot_y, 0], np.float32)
    head_point = np.array([foot_x, foot_y, height], np.float32)
    
    bottom, top = zone["bottom"], zone["top"]
    
    # Check if the foot point is inside the bottom polygon
    if cv2.pointPolygonTest(bottom[:, :2].astype(np.int32), (foot_x, foot_y), False) >= 0:
        min_z, max_z = np.min(bottom[:, 2]), np.max(top[:, 2])
        return min_z <= head_point[2] <= max_z
    return False

def is_outside_business_hours(zone_name):
    current_time = time.strftime("%H:%M:%S")
    opening_time = intrusion_zone_3D[zone_name]["opening_time"]
    closing_time = intrusion_zone_3D[zone_name]["closing_time"]

    # In case the closing time is on the next day
    if closing_time < opening_time:
        if current_time >= opening_time:
            return False  # In opening time
        if current_time < closing_time:
            return True   # Out of closing time

    # In case the closing time is on the same day
    return current_time < opening_time or current_time >= closing_time

# %%
# Create intrusion zone 

cap = cv2.VideoCapture(vid_path)
cv2.namedWindow("Select Intrusion Zone")
cv2.setMouseCallback("Select Intrusion Zone", mouse_callback)

while True:
    ret, frame = cap.read()
    if not ret:
        break
    
    for point in current_zone:
        cv2.circle(frame, point, 5, (0, 255, 0), -1)
    if len(current_zone) > 1:
        cv2.polylines(frame, [np.array(current_zone, np.int32)], isClosed=True, color=(0, 255, 255), thickness=2)
    
    for zone_name, zone in intrusion_zone_3D.items():
        text = f"{zone_name}: {zone['opening_time']} - {zone['closing_time']}"
        cv2.putText(frame, text, (20, 30 * (int(zone_name.split('_')[1]) + 1)), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
    
    cv2.imshow("Select Intrusion Zone", frame)
    key = cv2.waitKey(1) & 0xFF
    if key == ord("q"):
        break
    elif key == ord("c"):
        create_intrusion_zone()

cv2.destroyAllWindows()
cap.release()
print("Vùng intrusion đã được tạo: ", intrusion_zone_3D)
# Out:
# Successfully created intrusion zone_1 with open time 08:00:00 - 13:00:00
# Successfully created intrusion zone_2 with open time 08:00:00 - 13:00:00
# Vùng intrusion đã được tạo:  {'zone_1': {'bottom': array([[        163,         251,           0],
#        [        309,         179,           0],
#        [        530,         387,           0],
#        [        549,         475,           0],
#        [        498,         559,           0],
#        [        254,         715,           0],
#        [        155,         719,           0]], dtype=float32), 'top': array([[        163,         251,         180],
#        [        309,         179,         180],
#        [        530,         387,         180],
#        [        549,         475,         180],
#        [        498,         559,         180],
#        [        254,         715,         180],
#        [        155,         719,         180]], dtype=float32), 'closing_time': '13:00:00', 'opening_time': '08:00:00'}, 'zone_2': {'bottom': array([[        466,         129,           0],
#        [        772,         255,           0],
#        [        851,         267,           0],
#        [        907,         256,           0],
#        [       1002,         173,           0],
#        [        648,          53,           0]], dtype=float32), 'top': array([[        466,         129,         180],
#        [        772,         255,         180],
#        [        851,         267,         180],
#        [        907,         256,         180],
#        [       1002,         173,         180],
#        [        648,          53,         180]], dtype=float32), 'closing_time': '13:00:00', 'opening_time': '08:00:00'}}

# %%
# Open camera or video file
#cap = cv2.VideoCapture(0)  # Replace video file if needed: cap = cv2.VideoCapture("test.mp4")
cap = cv2.VideoCapture(vid_path)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Draw intrusion zones
    for zone in intrusion_zone_3D.values():
        bottom = zone["bottom"][:, :2].astype(np.int32)
        top = zone["top"][:, :2].astype(np.int32) + np.array([0, -200])  # Move the top plane up
        
        cv2.polylines(frame, [bottom.reshape((-1, 1, 2))], isClosed=True, color=(0, 0, 255), thickness=2)
        cv2.polylines(frame, [top.reshape((-1, 1, 2))], isClosed=True, color=(0, 0, 255), thickness=2)

        closing_time_text = f"Open time: {zone['opening_time']} - {zone['closing_time']}"
        text_position = (bottom[0][0], bottom[0][1] - 10)
        cv2.putText(frame, closing_time_text, text_position, cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
        
        for b, t in zip(bottom, top):
            cv2.line(frame, tuple(b), tuple(t), (0, 255, 255), 2)  # draw lines between bottom and top
    
    # Detect people using YOLO
    results = model(frame)
    detections = []
    
    for result in results:
        for box in result.boxes:
            x_min, y_min, x_max, y_max = map(int, box.xyxy[0])
            confidence = float(box.conf[0])
            class_id = int(box.cls[0])

            if class_id == 0 and confidence > 0.5:
                detections.append(([x_min, y_min, x_max - x_min, y_max - y_min], confidence))

    # Update tracker
    tracks = tracker.update_tracks(detections, frame=frame)

    for track in tracks:
        if not track.is_confirmed():
            continue

        track_id = track.track_id
        ltrb = track.to_ltrb()
        x_min, y_min, x_max, y_max = map(int, ltrb)
        
        for zone_name, zone in intrusion_zone_3D.items():
            if is_outside_business_hours(zone_name) and is_person_inside_intrusion_zone((x_min, y_min, x_max, y_max), zone):
                if track_id not in intrusion_timers:
                    intrusion_timers[track_id] = {"zone_1": None, "zone_2": None}
                
                if intrusion_timers[track_id][zone_name] is None:
                    intrusion_timers[track_id][zone_name] = time.time()
                    intrusion_logs[zone_name].setdefault(track_id, []).append(time.strftime("%Y-%m-%d %H:%M:%S"))
                
                elapsed_time = time.time() - intrusion_timers[track_id][zone_name]
                if elapsed_time >= INTRUSION_THRESHOLD:
                    color = (0, 0, 255)
                    text = f"Intruder {track_id} ({int(elapsed_time)}s) in {zone_name}"
                else:
                    color = (0, 255, 255)
                    text = f"Warning {track_id} ({int(elapsed_time)}s) in {zone_name}"
                
                cv2.rectangle(frame, (x_min, y_min), (x_max, y_max), color, 2)
                cv2.putText(frame, text, (x_min, y_min - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
            else:
                if track_id in intrusion_timers and intrusion_timers[track_id][zone_name] is not None:
                    intrusion_timers[track_id][zone_name] = None
    
    cv2.imshow("Intrusion Detection", frame)
    
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 6 persons, 358.7ms
# Speed: 3.4ms preprocess, 358.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 393.8ms
# Speed: 1.7ms preprocess, 393.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 399.2ms
# Speed: 2.1ms preprocess, 399.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 350.9ms
# Speed: 1.5ms preprocess, 350.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 368.8ms
# Speed: 2.0ms preprocess, 368.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 396.0ms
# Speed: 2.1ms preprocess, 396.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 363.5ms
# Speed: 1.5ms preprocess, 363.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 351.7ms
# Speed: 1.7ms preprocess, 351.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 357.9ms
# Speed: 2.1ms preprocess, 357.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 354.1ms
# Speed: 1.8ms preprocess, 354.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 358.9ms
# Speed: 1.6ms preprocess, 358.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 362.3ms
# Speed: 2.1ms preprocess, 362.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 355.8ms
# Speed: 2.2ms preprocess, 355.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 358.8ms
# Speed: 2.0ms preprocess, 358.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 359.1ms
# Speed: 2.3ms preprocess, 359.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 365.1ms
# Speed: 1.6ms preprocess, 365.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 371.7ms
# Speed: 2.1ms preprocess, 371.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 352.5ms
# Speed: 1.9ms preprocess, 352.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 345.5ms
# Speed: 2.0ms preprocess, 345.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 353.5ms
# Speed: 1.5ms preprocess, 353.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 351.4ms
# Speed: 1.6ms preprocess, 351.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 344.2ms
# Speed: 2.1ms preprocess, 344.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 347.3ms
# Speed: 1.7ms preprocess, 347.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 345.5ms
# Speed: 1.7ms preprocess, 345.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 346.1ms
# Speed: 1.8ms preprocess, 346.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 346.8ms
# Speed: 1.8ms preprocess, 346.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 345.4ms
# Speed: 2.0ms preprocess, 345.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 chair, 346.8ms
# Speed: 2.3ms preprocess, 346.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 chair, 349.1ms
# Speed: 1.8ms preprocess, 349.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 chair, 346.7ms
# Speed: 2.0ms preprocess, 346.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 346.3ms
# Speed: 2.1ms preprocess, 346.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 341.3ms
# Speed: 2.1ms preprocess, 341.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 chair, 339.6ms
# Speed: 1.9ms preprocess, 339.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 chair, 343.7ms
# Speed: 2.1ms preprocess, 343.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 chair, 340.7ms
# Speed: 1.6ms preprocess, 340.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 chair, 345.4ms
# Speed: 2.1ms preprocess, 345.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 346.0ms
# Speed: 1.6ms preprocess, 346.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 chair, 341.4ms
# Speed: 2.2ms preprocess, 341.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 chair, 342.6ms
# Speed: 1.8ms preprocess, 342.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 chair, 346.8ms
# Speed: 1.7ms preprocess, 346.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 chair, 347.4ms
# Speed: 1.7ms preprocess, 347.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 349.4ms
# Speed: 1.6ms preprocess, 349.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 347.3ms
# Speed: 1.8ms preprocess, 347.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 chair, 343.9ms
# Speed: 1.7ms preprocess, 343.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 chair, 360.2ms
# Speed: 2.1ms preprocess, 360.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 chair, 356.1ms
# Speed: 1.9ms preprocess, 356.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 chair, 354.7ms
# Speed: 2.1ms preprocess, 354.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 365.5ms
# Speed: 2.0ms preprocess, 365.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 chair, 350.8ms
# Speed: 2.0ms preprocess, 350.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons,
7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 340.6ms
# Speed: 1.6ms preprocess, 340.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 341.3ms
# Speed: 1.6ms preprocess, 341.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 347.8ms
# Speed: 1.5ms preprocess, 347.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 348.8ms
# Speed: 1.9ms preprocess, 348.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 341.1ms
# Speed: 1.9ms preprocess, 341.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 349.3ms
# Speed: 1.5ms preprocess, 349.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 390.9ms
# Speed: 2.7ms preprocess, 390.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 379.9ms
# Speed: 1.8ms preprocess, 379.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 368.4ms
# Speed: 2.1ms preprocess, 368.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 368.6ms
# Speed: 1.7ms preprocess, 368.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 364.4ms
# Speed: 2.0ms preprocess, 364.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 366.3ms
# Speed: 2.1ms preprocess, 366.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 369.6ms
# Speed: 2.0ms preprocess, 369.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 367.4ms
# Speed: 2.0ms preprocess, 367.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 347.0ms
# Speed: 1.9ms preprocess, 347.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 351.3ms
# Speed: 2.0ms preprocess, 351.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 366.3ms
# Speed: 2.2ms preprocess, 366.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 345.5ms
# Speed: 1.6ms preprocess, 345.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 350.7ms
# Speed: 1.9ms preprocess, 350.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 353.5ms
# Speed: 2.2ms preprocess, 353.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 347.3ms
# Speed: 1.9ms preprocess, 347.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 370.7ms
# Speed: 2.7ms preprocess, 370.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 352.3ms
# Speed: 1.9ms preprocess, 352.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 345.6ms
# Speed: 2.6ms preprocess, 345.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 349.3ms
# Speed: 2.4ms preprocess, 349.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 351.1ms
# Speed: 2.4ms preprocess, 351.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 346.1ms
# Speed: 3.3ms preprocess, 346.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 363.4ms
# Speed: 2.6ms preprocess, 363.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 379.2ms
# Speed: 2.5ms preprocess, 379.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 344.1ms
# Speed: 2.8ms preprocess, 344.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 343.6ms
# Speed: 1.8ms preprocess, 343.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 347.9ms
# Speed: 2.0ms preprocess, 347.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 347.6ms
# Speed: 1.8ms preprocess, 347.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 349.5ms
# Speed: 1.9ms preprocess, 349.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 348.6ms
# Speed: 1.9ms preprocess, 348.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 350.9ms
# Speed: 1.7ms preprocess, 350.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 345.3ms
# Speed: 1.6ms preprocess, 345.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 341.1ms
# Speed: 2.5ms preprocess, 341.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 346.2ms
# Speed: 2.2ms preprocess, 346.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 354.0ms
# Speed: 1.7ms preprocess, 354.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 359.0ms
# Speed: 1.6ms preprocess, 359.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 349.9ms
# Speed: 1.8ms preprocess, 349.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 348.7ms
# Speed: 2.4ms preprocess, 348.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 349.5ms
# Speed: 2.4ms preprocess, 349.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)

# %%
# Print intrusion logs
print("\nIntrusion Log:")
for zone, logs in intrusion_logs.items():
    print(f"\n {zone.upper()}:")
    for person_id, timestamps in logs.items():
        print(f" - Person ID {person_id}: {timestamps}")
# Out:
# Intrusion Log:
#
#  ZONE_1:
#  - Person ID 2: ['2025-03-02 14:31:58']
#  - Person ID 4: ['2025-03-02 14:31:58']
#  - Person ID 5: ['2025-03-02 14:31:59']
#  - Person ID 6: ['2025-03-02 14:32:18']
#  - Person ID 7: ['2025-03-02 14:32:28']
#  - Person ID 8: ['2025-03-02 14:32:36']
#  - Person ID 14: ['2025-03-02 14:32:49']
#  - Person ID 19: ['2025-03-02 14:33:10']
#  - Person ID 24: ['2025-03-02 14:33:30']
#  - Person ID 29: ['2025-03-02 14:34:00']
#
#  ZONE_2:
